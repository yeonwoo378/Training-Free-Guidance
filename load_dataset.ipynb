# %%
import os

from datasets import load_dataset
ds = load_dataset("sandorvasas/celeba-hq-256")
print(ds)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image'],
#         num_rows: 24000
#     })
#     test: Dataset({
#         features: ['image'],
#         num_rows: 6000
#     })
# })

# %%
# ds['test'][0]['image']
data_path = 'data/celeba_hq_256'
for i in range(6000):
    img = ds['test'][i]['image']
    img.save(os.path.join(data_path, f'{str(i).zfill(4)}.png'))
